# %%
import numpy as np

# %% [markdown]
# # SBEND Benchmarking
#
# Default uses arc length of 0.5 m and bend angle of $\pi / 2$. The arc length is entered directly into elegant for SBEND.L while OPAL the chord length is used to set SBEND.L (calculated from the arc length and bend angle).
#
# From SLAC-75 for a dipole:
#
# $R_{11} = cos(k_x L)$
#
# $R_{12} = -k_x sin(k_x L)$
#
# Where $k_x = \sqrt{1-n} / R$, $R$ is the bending radius, $L$ is the arc length, and $n$ is the magnet index which is normally $0$ for pure dipole.
#
# For our settings this should give easy to work with values of
#
# $R_{11} = 0$
#
# $R_{12} = -\pi$

# %% [markdown]
# ### Element Settings

# %%
arc_length = 0.5
bend_angle = np.pi / 2.
bend_radius = arc_length / bend_angle

chord_length = 2 * bend_radius * np.sin(bend_angle / 2.)

# %%
# Arc length if use a chord length of 0.5
# 0.5 / (2  * np.sin(bend_angle / 2.)) * bend_angle

# %%
def r11_dipole(radius, length):
    n = 0
    kx = np.sqrt(1 - n) / radius
    R11 = np.cos(kx * length)
    
    return R11

def r12_dipole(radius, length):
    n = 0
    kx = np.sqrt(1 - n) / radius
    R12 = -kx * np.sin(kx * length)
    
    return R12

# %% [markdown]
# ### Verify calculation

# %%
r11_dipole(bend_radius, arc_length)
# Out:
# 6.123233995736766e-17

# %%
r12_dipole(bend_radius, arc_length)
# Out:
# -3.141592653589793

# %% [markdown]
# # Distribution

# %% [markdown]
# Both simulations use a single particle with coordinates:
#
# x, xp, y, yp, t, p = 1e-3, 0, 0, 0, 0, 273.97134
#
# The transverse momenta units differ between elegant and OPAL but are initially zero so it should not matter. Other units are the same bewteen the two codes.
#
# The final result should be immediately after the dipole edge face:
#
# $x_f = R_{11} * x_0 + R_{12} x'_0 = 0.$
#
# $x'_f = R_{11} * x_0 + R_{12} x'_0 = \pi \, \times 10^{-3}$

# %% [markdown]
# # OPAL

# %% [markdown]
# OPAL simulation uses very small time step (1 fs) to get good accuracy. Some of this may be down to the 'almost' hard edge field on the dipole that needs to be integrated through as accurately as possible.
#
# The monitor is also not positioned exactly at the dipole exit right now so the $x_f$ value may not be close to 0. Positioning the monitor downstream of the dipole still allows for verifying $x'_f$ though.

# %% [markdown]
# #### Run

# %%
! opal opal.in
# Out:
# Ippl> CommMPI: Parent process waiting for children ...
# Ippl> CommMPI: Initialization complete.
# >                ____  _____       ___
# >               / __ \|  __ \ /\   | |
# >              | |  | | |__) /  \  | |
# >              | |  | |  ___/ /\ \ | |
# >              | |__| | |  / ____ \| |____
# >               \____/|_| /_/    \_\______|
# OPAL>
# OPAL> This is OPAL (Object Oriented Parallel Accelerator Library) Version 2.2.0
# OPAL>                                 git rev.
# OPAL>
# OPAL>
# OPAL>                      (c) PSI, http://amas.web.psi.ch
# OPAL>
# OPAL>
# OPAL> The optimiser (former opt-Pilot) is integrated
# OPAL>
# OPAL> Please send cookies, goodies or other motivations (wine and beer ... )
# OPAL> to the OPAL developers opal@lists.psi.ch
# OPAL>
# OPAL> Time: 18:30:16 date: 02/09/2020
# OPAL>
# OPAL> Couldn't find startup file "/home/vagrant/init.opal".
# OPAL> Note: this is not mandatory for an OPAL simulation!
# OPAL>
# OPAL> * Reading input stream "opal.in".
# OPAL>
# OPAL> value: {GAMMA*BETA,EMASS,P0}={273.971,0.000510999,0.139999}
# OPAL>
# OPAL>
# OPAL> value: {ARC_LENGTH,BEND_ANGLE,CHORD_LENGTH}={0.5,1.5708,0.450158}
# OPAL>
# OPAL> * **********************************************************************************
# OPAL> * Selected Tracking Method == PARALLEL-T, NEW TRACK
# OPAL> * **********************************************************************************
# Ippl> no solver attached
# OPAL>
# OPAL> --------------------------------------------------
# OPAL> Warning!! The number of particles in the initial
# OPAL> distribution is 1.
# OPAL>
# OPAL> This is different from the number of particles
# OPAL> defined by the BEAM command: 50000
# OPAL>
# OPAL> This is often happens when using a FROMFILE type
# OPAL> distribution and not matching the number of
# OPAL> particles in the particles file(s) with the number
# OPAL> given in the BEAM command.
# OPAL>
# OPAL> The number of particles in the initial distribution
# OPAL> (1) will take precedence.
# OPAL> ---------------------------------------------------
# OPAL>
# Ippl> Creating new file for data: opal.stat
# Ippl> Creating new file for data: opal.lbal
# OPAL>
# OPAL> * ************* D I S T R I B U T I O N ********************************************
# OPAL> *
# OPAL> * Number of particles: 1
# OPAL> *
# OPAL> * Distribution type: FROMFILE
# OPAL> *
# OPAL> * Input file:        bunch_opal.txt
# OPAL> *
# OPAL> * Distribution is injected.
# OPAL> *
# OPAL> * **********************************************************************************
# OPAL>
# OPAL> * ************* B E A M ************************************************************
# OPAL> * BEAM        BEAM1
# OPAL> * PARTICLE    ELECTRON
# OPAL> * CURRENT     0.000000e+00 A
# OPAL> * FREQUENCY   1.000000e+06 MHz
# OPAL> * CHARGE      -e * 1.000000e+00
# OPAL> * REST MASS   5.109990e-04 GeV
# OPAL> * MOMENTUM    1.399991e-01
# OPAL> * NPART       5.000000e+04
# OPAL> * **********************************************************************************
# OPAL>
# OPAL> * ************* F I E L D S O L V E R **********************************************
# OPAL> * FIELDSOLVER  FS_SC
# OPAL> * TYPE         NONE
# OPAL> * N-PROCESSORS 1
# OPAL> * MX           3.200000e+01
# OPAL> * MY           3.200000e+01
# OPAL> * MT           3.200000e+01
# OPAL> * BBOXINCR     1.000000e+00
# OPAL> * XDIM         serial
# OPAL> * YDIM         serial
# OPAL> * Z(T)DIM      parallel
# OPAL> * **********************************************************************************
# OPAL>
# OPAL>
# OPAL> Size of map 5 sections
# OPAL> Key: (0.000000 - 0.100000) number of overlapping elements 1
# OPAL>                            START_DRIFT
# OPAL> Key: (0.100000 - 0.600000) number of overlapping elements 1
# OPAL>                            DIPOLE
# OPAL> Key: (0.600000 - 1.035158) number of overlapping elements 0
# OPAL> Key: (1.035158 - 1.045158) number of overlapping elements 1
# OPAL>                            MON
# OPAL> Key: (1.045158 - 1.915475) number of overlapping elements 0
# OPAL>
# Ippl> Creating new file for data: data/opal_ElementPositions.sdds
# OPAL>
# OPAL> * ************** B U N C H *********************************************************
# OPAL> * NP              = 1
# OPAL> * Qtot            =        0.000 [fC]         Qi    =        0.000 [fC]
# OPAL> * Ekin            =     139.489 [MeV]         dEkin =        0.000 [eV]
# OPAL> * rmax            = (      1.00000 ,      0.00000 ,      0.00000 ) [mm]
# OPAL> * rmin            = (      1.00000 ,      0.00000 ,      0.00000 ) [mm]
# OPAL> * hr              = (      0.00001 ,      0.00001 ,      0.00001 ) [um]
# OPAL> * dh              =   1.00000e-10 [%]
# OPAL> * t               =        0.000 [fs]         dT    =        1.000 [fs]
# OPAL> * spos            =        0.000 [um]
# OPAL> * **********************************************************************************
# OPAL>
# OPAL> Track start at: 18:30:23, t= 0.000 [fs]; zstart at: 0.000 [um]
# OPAL> Executing ParallelTTracker, initial dt= 1.000 [fs];
# OPAL> max integration steps 10000000, next step= 0
# ParallelTTracker > 18:30:23 Step    999; only    1 particles emitted; t= 1.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   1999; only    1 particles emitted; t= 2.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   2999; only    1 particles emitted; t= 3.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   3999; only    1 particles emitted; t= 4.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   4999; only    1 particles emitted; t= 5.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   5999; only    1 particles emitted; t= 6.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   6999; only    1 particles emitted; t= 7.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   7999; only    1 particles emitted; t= 8.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   8999; only    1 particles emitted; t= 9.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step   9999; only    1 particles emitted; t= 10.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:23 Step  10999; only    1 particles emitted; t= 11.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  11999; only    1 particles emitted; t= 12.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  12999; only    1 particles emitted; t= 13.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  13999; only    1 particles emitted; t= 14.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  14999; only    1 particles emitted; t= 15.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  15999; only    1 particles emitted; t= 16.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  16999; only    1 particles emitted; t= 17.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  17999; only    1 particles emitted; t= 18.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  18999; only    1 particles emitted; t= 19.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  19999; only    1 particles emitted; t= 20.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  20999; only    1 particles emitted; t= 21.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  21999; only    1 particles emitted; t= 22.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  22999; only    1 particles emitted; t= 23.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  23999; only    1 particles emitted; t= 24.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  24999; only    1 particles emitted; t= 25.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  25999; only    1 particles emitted; t= 26.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  26999; only    1 particles emitted; t= 27.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  27999; only    1 particles emitted; t= 28.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  28999; only    1 particles emitted; t= 29.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  29999; only    1 particles emitted; t= 30.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  30999; only    1 particles emitted; t= 31.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  31999; only    1 particles emitted; t= 32.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  32999; only    1 particles emitted; t= 33.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  33999; only    1 particles emitted; t= 34.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  34999; only    1 particles emitted; t= 35.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  35999; only    1 particles emitted; t= 36.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  36999; only    1 particles emitted; t= 37.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  37999; only    1 particles emitted; t= 38.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  38999; only    1 particles emitted; t= 39.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  39999; only    1 particles emitted; t= 40.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  40999; only    1 particles emitted; t= 41.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  41999; only    1 particles emitted; t= 42.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:24 Step  42999; only    1 particles emitted; t= 43.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  43999; only    1 particles emitted; t= 44.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  44999; only    1 particles emitted; t= 45.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  45999; only    1 particles emitted; t= 46.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  46999; only    1 particles emitted; t= 47.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  47999; only    1 particles emitted; t= 48.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  48999; only    1 particles emitted; t= 49.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  49999; only    1 particles emitted; t= 50.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  50999; only    1 particles emitted; t= 51.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  51999; only    1 particles emitted; t= 52.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  52999; only    1 particles emitted; t= 53.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  53999; only    1 particles emitted; t= 54.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  54999; only    1 particles emitted; t= 55.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  55999; only    1 particles emitted; t= 56.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  56999; only    1 particles emitted; t= 57.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  57999; only    1 particles emitted; t= 58.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  58999; only    1 particles emitted; t= 59.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  59999; only    1 particles emitted; t= 60.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  60999; only    1 particles emitted; t= 61.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  61999; only    1 particles emitted; t= 62.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  62999; only    1 particles emitted; t= 63.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  63999; only    1 particles emitted; t= 64.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  64999; only    1 particles emitted; t= 65.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  65999; only    1 particles emitted; t= 66.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  66999; only    1 particles emitted; t= 67.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  67999; only    1 particles emitted; t= 68.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  68999; only    1 particles emitted; t= 69.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  69999; only    1 particles emitted; t= 70.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  70999; only    1 particles emitted; t= 71.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  71999; only    1 particles emitted; t= 72.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  72999; only    1 particles emitted; t= 73.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:25 Step  73999; only    1 particles emitted; t= 74.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  74999; only    1 particles emitted; t= 75.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  75999; only    1 particles emitted; t= 76.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  76999; only    1 particles emitted; t= 77.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  77999; only    1 particles emitted; t= 78.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  78999; only    1 particles emitted; t= 79.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  79999; only    1 particles emitted; t= 80.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  80999; only    1 particles emitted; t= 81.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  81999; only    1 particles emitted; t= 82.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  82999; only    1 particles emitted; t= 83.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  83999; only    1 particles emitted; t= 84.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  84999; only    1 particles emitted; t= 85.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  85999; only    1 particles emitted; t= 86.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  86999; only    1 particles emitted; t= 87.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  87999; only    1 particles emitted; t= 88.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  88999; only    1 particles emitted; t= 89.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  89999; only    1 particles emitted; t= 90.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  90999; only    1 particles emitted; t= 91.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  91999; only    1 particles emitted; t= 92.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  92999; only    1 particles emitted; t= 93.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  93999; only    1 particles emitted; t= 94.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  94999; only    1 particles emitted; t= 95.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  95999; only    1 particles emitted; t= 96.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  96999; only    1 particles emitted; t= 97.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  97999; only    1 particles emitted; t= 98.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  98999; only    1 particles emitted; t= 99.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step  99999; only    1 particles emitted; t= 100.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step 100999; only    1 particles emitted; t= 101.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step 101999; only    1 particles emitted; t= 102.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step 102999; only    1 particles emitted; t= 103.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step 103999; only    1 particles emitted; t= 104.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step 104999; only    1 particles emitted; t= 105.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:26 Step 105999; only    1 particles emitted; t= 106.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 106999; only    1 particles emitted; t= 107.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 107999; only    1 particles emitted; t= 108.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 108999; only    1 particles emitted; t= 109.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 109999; only    1 particles emitted; t= 110.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 110999; only    1 particles emitted; t= 111.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 111999; only    1 particles emitted; t= 112.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 112999; only    1 particles emitted; t= 113.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 113999; only    1 particles emitted; t= 114.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 114999; only    1 particles emitted; t= 115.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 115999; only    1 particles emitted; t= 116.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 116999; only    1 particles emitted; t= 117.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 117999; only    1 particles emitted; t= 118.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 118999; only    1 particles emitted; t= 119.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 119999; only    1 particles emitted; t= 120.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 120999; only    1 particles emitted; t= 121.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 121999; only    1 particles emitted; t= 122.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 122999; only    1 particles emitted; t= 123.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 123999; only    1 particles emitted; t= 124.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 124999; only    1 particles emitted; t= 125.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 125999; only    1 particles emitted; t= 126.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 126999; only    1 particles emitted; t= 127.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 127999; only    1 particles emitted; t= 128.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 128999; only    1 particles emitted; t= 129.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 129999; only    1 particles emitted; t= 130.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 130999; only    1 particles emitted; t= 131.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 131999; only    1 particles emitted; t= 132.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 132999; only    1 particles emitted; t= 133.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 133999; only    1 particles emitted; t= 134.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 134999; only    1 particles emitted; t= 135.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 135999; only    1 particles emitted; t= 136.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:27 Step 136999; only    1 particles emitted; t= 137.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 137999; only    1 particles emitted; t= 138.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 138999; only    1 particles emitted; t= 139.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 139999; only    1 particles emitted; t= 140.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 140999; only    1 particles emitted; t= 141.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 141999; only    1 particles emitted; t= 142.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 142999; only    1 particles emitted; t= 143.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 143999; only    1 particles emitted; t= 144.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 144999; only    1 particles emitted; t= 145.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 145999; only    1 particles emitted; t= 146.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 146999; only    1 particles emitted; t= 147.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 147999; only    1 particles emitted; t= 148.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 148999; only    1 particles emitted; t= 149.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 149999; only    1 particles emitted; t= 150.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 150999; only    1 particles emitted; t= 151.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 151999; only    1 particles emitted; t= 152.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 152999; only    1 particles emitted; t= 153.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 153999; only    1 particles emitted; t= 154.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 154999; only    1 particles emitted; t= 155.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 155999; only    1 particles emitted; t= 156.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 156999; only    1 particles emitted; t= 157.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 157999; only    1 particles emitted; t= 158.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 158999; only    1 particles emitted; t= 159.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 159999; only    1 particles emitted; t= 160.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 160999; only    1 particles emitted; t= 161.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 161999; only    1 particles emitted; t= 162.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 162999; only    1 particles emitted; t= 163.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 163999; only    1 particles emitted; t= 164.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 164999; only    1 particles emitted; t= 165.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 165999; only    1 particles emitted; t= 166.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 166999; only    1 particles emitted; t= 167.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 167999; only    1 particles emitted; t= 168.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:28 Step 168999; only    1 particles emitted; t= 169.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 169999; only    1 particles emitted; t= 170.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 170999; only    1 particles emitted; t= 171.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 171999; only    1 particles emitted; t= 172.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 172999; only    1 particles emitted; t= 173.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 173999; only    1 particles emitted; t= 174.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 174999; only    1 particles emitted; t= 175.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 175999; only    1 particles emitted; t= 176.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 176999; only    1 particles emitted; t= 177.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 177999; only    1 particles emitted; t= 178.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 178999; only    1 particles emitted; t= 179.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 179999; only    1 particles emitted; t= 180.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 180999; only    1 particles emitted; t= 181.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 181999; only    1 particles emitted; t= 182.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 182999; only    1 particles emitted; t= 183.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 183999; only    1 particles emitted; t= 184.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 184999; only    1 particles emitted; t= 185.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 185999; only    1 particles emitted; t= 186.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 186999; only    1 particles emitted; t= 187.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 187999; only    1 particles emitted; t= 188.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 188999; only    1 particles emitted; t= 189.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 189999; only    1 particles emitted; t= 190.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 190999; only    1 particles emitted; t= 191.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 191999; only    1 particles emitted; t= 192.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 192999; only    1 particles emitted; t= 193.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 193999; only    1 particles emitted; t= 194.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 194999; only    1 particles emitted; t= 195.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 195999; only    1 particles emitted; t= 196.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 196999; only    1 particles emitted; t= 197.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 197999; only    1 particles emitted; t= 198.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 198999; only    1 particles emitted; t= 199.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 199999; only    1 particles emitted; t= 200.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:29 Step 200999; only    1 particles emitted; t= 201.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 201999; only    1 particles emitted; t= 202.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 202999; only    1 particles emitted; t= 203.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 203999; only    1 particles emitted; t= 204.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 204999; only    1 particles emitted; t= 205.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 205999; only    1 particles emitted; t= 206.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 206999; only    1 particles emitted; t= 207.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 207999; only    1 particles emitted; t= 208.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 208999; only    1 particles emitted; t= 209.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 209999; only    1 particles emitted; t= 210.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 210999; only    1 particles emitted; t= 211.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 211999; only    1 particles emitted; t= 212.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 212999; only    1 particles emitted; t= 213.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 213999; only    1 particles emitted; t= 214.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 214999; only    1 particles emitted; t= 215.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 215999; only    1 particles emitted; t= 216.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 216999; only    1 particles emitted; t= 217.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 217999; only    1 particles emitted; t= 218.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 218999; only    1 particles emitted; t= 219.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 219999; only    1 particles emitted; t= 220.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 220999; only    1 particles emitted; t= 221.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 221999; only    1 particles emitted; t= 222.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 222999; only    1 particles emitted; t= 223.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 223999; only    1 particles emitted; t= 224.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 224999; only    1 particles emitted; t= 225.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 225999; only    1 particles emitted; t= 226.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 226999; only    1 particles emitted; t= 227.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 227999; only    1 particles emitted; t= 228.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 228999; only    1 particles emitted; t= 229.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 229999; only    1 particles emitted; t= 230.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 230999; only    1 particles emitted; t= 231.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:30 Step 231999; only    1 particles emitted; t= 232.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 232999; only    1 particles emitted; t= 233.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 233999; only    1 particles emitted; t= 234.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 234999; only    1 particles emitted; t= 235.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 235999; only    1 particles emitted; t= 236.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 236999; only    1 particles emitted; t= 237.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 237999; only    1 particles emitted; t= 238.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 238999; only    1 particles emitted; t= 239.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 239999; only    1 particles emitted; t= 240.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 240999; only    1 particles emitted; t= 241.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 241999; only    1 particles emitted; t= 242.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 242999; only    1 particles emitted; t= 243.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 243999; only    1 particles emitted; t= 244.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 244999; only    1 particles emitted; t= 245.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 245999; only    1 particles emitted; t= 246.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 246999; only    1 particles emitted; t= 247.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 247999; only    1 particles emitted; t= 248.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 248999; only    1 particles emitted; t= 249.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 249999; only    1 particles emitted; t= 250.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 250999; only    1 particles emitted; t= 251.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 251999; only    1 particles emitted; t= 252.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 252999; only    1 particles emitted; t= 253.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 253999; only    1 particles emitted; t= 254.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 254999; only    1 particles emitted; t= 255.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 255999; only    1 particles emitted; t= 256.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 256999; only    1 particles emitted; t= 257.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 257999; only    1 particles emitted; t= 258.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 258999; only    1 particles emitted; t= 259.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 259999; only    1 particles emitted; t= 260.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 260999; only    1 particles emitted; t= 261.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 261999; only    1 particles emitted; t= 262.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:31 Step 262999; only    1 particles emitted; t= 263.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 263999; only    1 particles emitted; t= 264.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 264999; only    1 particles emitted; t= 265.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 265999; only    1 particles emitted; t= 266.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 266999; only    1 particles emitted; t= 267.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 267999; only    1 particles emitted; t= 268.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 268999; only    1 particles emitted; t= 269.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 269999; only    1 particles emitted; t= 270.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 270999; only    1 particles emitted; t= 271.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 271999; only    1 particles emitted; t= 272.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 272999; only    1 particles emitted; t= 273.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 273999; only    1 particles emitted; t= 274.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 274999; only    1 particles emitted; t= 275.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 275999; only    1 particles emitted; t= 276.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 276999; only    1 particles emitted; t= 277.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 277999; only    1 particles emitted; t= 278.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 278999; only    1 particles emitted; t= 279.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 279999; only    1 particles emitted; t= 280.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 280999; only    1 particles emitted; t= 281.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 281999; only    1 particles emitted; t= 282.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 282999; only    1 particles emitted; t= 283.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 283999; only    1 particles emitted; t= 284.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 284999; only    1 particles emitted; t= 285.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 285999; only    1 particles emitted; t= 286.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 286999; only    1 particles emitted; t= 287.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 287999; only    1 particles emitted; t= 288.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 288999; only    1 particles emitted; t= 289.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 289999; only    1 particles emitted; t= 290.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 290999; only    1 particles emitted; t= 291.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 291999; only    1 particles emitted; t= 292.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 292999; only    1 particles emitted; t= 293.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 293999; only    1 particles emitted; t= 294.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:32 Step 294999; only    1 particles emitted; t= 295.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 295999; only    1 particles emitted; t= 296.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 296999; only    1 particles emitted; t= 297.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 297999; only    1 particles emitted; t= 298.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 298999; only    1 particles emitted; t= 299.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 299999; only    1 particles emitted; t= 300.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 300999; only    1 particles emitted; t= 301.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 301999; only    1 particles emitted; t= 302.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 302999; only    1 particles emitted; t= 303.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 303999; only    1 particles emitted; t= 304.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 304999; only    1 particles emitted; t= 305.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 305999; only    1 particles emitted; t= 306.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 306999; only    1 particles emitted; t= 307.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 307999; only    1 particles emitted; t= 308.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 308999; only    1 particles emitted; t= 309.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 309999; only    1 particles emitted; t= 310.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 310999; only    1 particles emitted; t= 311.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 311999; only    1 particles emitted; t= 312.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 312999; only    1 particles emitted; t= 313.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 313999; only    1 particles emitted; t= 314.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 314999; only    1 particles emitted; t= 315.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 315999; only    1 particles emitted; t= 316.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 316999; only    1 particles emitted; t= 317.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 317999; only    1 particles emitted; t= 318.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 318999; only    1 particles emitted; t= 319.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 319999; only    1 particles emitted; t= 320.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 320999; only    1 particles emitted; t= 321.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 321999; only    1 particles emitted; t= 322.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 322999; only    1 particles emitted; t= 323.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 323999; only    1 particles emitted; t= 324.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 324999; only    1 particles emitted; t= 325.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:33 Step 325999; only    1 particles emitted; t= 326.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 326999; only    1 particles emitted; t= 327.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 327999; only    1 particles emitted; t= 328.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 328999; only    1 particles emitted; t= 329.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 329999; only    1 particles emitted; t= 330.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 330999; only    1 particles emitted; t= 331.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 331999; only    1 particles emitted; t= 332.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 332999; only    1 particles emitted; t= 333.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 333999; only    1 particles emitted; t= 334.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 334999; only    1 particles emitted; t= 335.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 335999; only    1 particles emitted; t= 336.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 336999; only    1 particles emitted; t= 337.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 337999; only    1 particles emitted; t= 338.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 338999; only    1 particles emitted; t= 339.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 339999; only    1 particles emitted; t= 340.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 340999; only    1 particles emitted; t= 341.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 341999; only    1 particles emitted; t= 342.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 342999; only    1 particles emitted; t= 343.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 343999; only    1 particles emitted; t= 344.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 344999; only    1 particles emitted; t= 345.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 345999; only    1 particles emitted; t= 346.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 346999; only    1 particles emitted; t= 347.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 347999; only    1 particles emitted; t= 348.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 348999; only    1 particles emitted; t= 349.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 349999; only    1 particles emitted; t= 350.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 350999; only    1 particles emitted; t= 351.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 351999; only    1 particles emitted; t= 352.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 352999; only    1 particles emitted; t= 353.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 353999; only    1 particles emitted; t= 354.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 354999; only    1 particles emitted; t= 355.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 355999; only    1 particles emitted; t= 356.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 356999; only    1 particles emitted; t= 357.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:34 Step 357999; only    1 particles emitted; t= 358.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 358999; only    1 particles emitted; t= 359.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 359999; only    1 particles emitted; t= 360.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 360999; only    1 particles emitted; t= 361.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 361999; only    1 particles emitted; t= 362.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 362999; only    1 particles emitted; t= 363.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 363999; only    1 particles emitted; t= 364.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 364999; only    1 particles emitted; t= 365.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 365999; only    1 particles emitted; t= 366.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 366999; only    1 particles emitted; t= 367.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 367999; only    1 particles emitted; t= 368.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 368999; only    1 particles emitted; t= 369.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 369999; only    1 particles emitted; t= 370.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 370999; only    1 particles emitted; t= 371.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 371999; only    1 particles emitted; t= 372.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 372999; only    1 particles emitted; t= 373.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 373999; only    1 particles emitted; t= 374.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 374999; only    1 particles emitted; t= 375.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 375999; only    1 particles emitted; t= 376.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 376999; only    1 particles emitted; t= 377.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 377999; only    1 particles emitted; t= 378.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 378999; only    1 particles emitted; t= 379.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 379999; only    1 particles emitted; t= 380.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 380999; only    1 particles emitted; t= 381.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 381999; only    1 particles emitted; t= 382.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 382999; only    1 particles emitted; t= 383.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 383999; only    1 particles emitted; t= 384.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 384999; only    1 particles emitted; t= 385.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 385999; only    1 particles emitted; t= 386.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 386999; only    1 particles emitted; t= 387.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 387999; only    1 particles emitted; t= 388.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:35 Step 388999; only    1 particles emitted; t= 389.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 389999; only    1 particles emitted; t= 390.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 390999; only    1 particles emitted; t= 391.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 391999; only    1 particles emitted; t= 392.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 392999; only    1 particles emitted; t= 393.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 393999; only    1 particles emitted; t= 394.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 394999; only    1 particles emitted; t= 395.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 395999; only    1 particles emitted; t= 396.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 396999; only    1 particles emitted; t= 397.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 397999; only    1 particles emitted; t= 398.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 398999; only    1 particles emitted; t= 399.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 399999; only    1 particles emitted; t= 400.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 400999; only    1 particles emitted; t= 401.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 401999; only    1 particles emitted; t= 402.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 402999; only    1 particles emitted; t= 403.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 403999; only    1 particles emitted; t= 404.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 404999; only    1 particles emitted; t= 405.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 405999; only    1 particles emitted; t= 406.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 406999; only    1 particles emitted; t= 407.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 407999; only    1 particles emitted; t= 408.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 408999; only    1 particles emitted; t= 409.000 [ps], E=139.489 [MeV],
# ParallelTTracker > 18:30:36 Step 409999; only    1 particles emitted; t= 410.000 [ps], E=139.489 [MeV],
# ...
# ParallelTTracker > 18:33:36 Step 6298999; only    1 particles emitted; t= 6.299 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6299999; only    1 particles emitted; t= 6.300 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6300999; only    1 particles emitted; t= 6.301 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6301999; only    1 particles emitted; t= 6.302 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6302999; only    1 particles emitted; t= 6.303 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6303999; only    1 particles emitted; t= 6.304 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6304999; only    1 particles emitted; t= 6.305 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6305999; only    1 particles emitted; t= 6.306 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6306999; only    1 particles emitted; t= 6.307 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6307999; only    1 particles emitted; t= 6.308 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6308999; only    1 particles emitted; t= 6.309 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6309999; only    1 particles emitted; t= 6.310 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6310999; only    1 particles emitted; t= 6.311 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6311999; only    1 particles emitted; t= 6.312 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6312999; only    1 particles emitted; t= 6.313 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6313999; only    1 particles emitted; t= 6.314 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6314999; only    1 particles emitted; t= 6.315 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:36 Step 6315999; only    1 particles emitted; t= 6.316 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6316999; only    1 particles emitted; t= 6.317 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6317999; only    1 particles emitted; t= 6.318 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6318999; only    1 particles emitted; t= 6.319 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6319999; only    1 particles emitted; t= 6.320 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6320999; only    1 particles emitted; t= 6.321 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6321999; only    1 particles emitted; t= 6.322 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6322999; only    1 particles emitted; t= 6.323 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6323999; only    1 particles emitted; t= 6.324 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6324999; only    1 particles emitted; t= 6.325 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6325999; only    1 particles emitted; t= 6.326 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6326999; only    1 particles emitted; t= 6.327 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6327999; only    1 particles emitted; t= 6.328 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6328999; only    1 particles emitted; t= 6.329 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6329999; only    1 particles emitted; t= 6.330 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6330999; only    1 particles emitted; t= 6.331 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6331999; only    1 particles emitted; t= 6.332 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6332999; only    1 particles emitted; t= 6.333 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6333999; only    1 particles emitted; t= 6.334 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6334999; only    1 particles emitted; t= 6.335 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6335999; only    1 particles emitted; t= 6.336 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6336999; only    1 particles emitted; t= 6.337 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6337999; only    1 particles emitted; t= 6.338 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6338999; only    1 particles emitted; t= 6.339 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6339999; only    1 particles emitted; t= 6.340 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6340999; only    1 particles emitted; t= 6.341 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6341999; only    1 particles emitted; t= 6.342 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6342999; only    1 particles emitted; t= 6.343 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6343999; only    1 particles emitted; t= 6.344 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6344999; only    1 particles emitted; t= 6.345 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6345999; only    1 particles emitted; t= 6.346 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6346999; only    1 particles emitted; t= 6.347 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6347999; only    1 particles emitted; t= 6.348 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6348999; only    1 particles emitted; t= 6.349 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:37 Step 6349999; only    1 particles emitted; t= 6.350 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6350999; only    1 particles emitted; t= 6.351 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6351999; only    1 particles emitted; t= 6.352 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6352999; only    1 particles emitted; t= 6.353 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6353999; only    1 particles emitted; t= 6.354 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6354999; only    1 particles emitted; t= 6.355 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6355999; only    1 particles emitted; t= 6.356 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6356999; only    1 particles emitted; t= 6.357 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6357999; only    1 particles emitted; t= 6.358 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6358999; only    1 particles emitted; t= 6.359 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6359999; only    1 particles emitted; t= 6.360 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6360999; only    1 particles emitted; t= 6.361 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6361999; only    1 particles emitted; t= 6.362 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6362999; only    1 particles emitted; t= 6.363 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6363999; only    1 particles emitted; t= 6.364 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6364999; only    1 particles emitted; t= 6.365 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6365999; only    1 particles emitted; t= 6.366 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6366999; only    1 particles emitted; t= 6.367 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6367999; only    1 particles emitted; t= 6.368 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6368999; only    1 particles emitted; t= 6.369 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6369999; only    1 particles emitted; t= 6.370 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6370999; only    1 particles emitted; t= 6.371 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6371999; only    1 particles emitted; t= 6.372 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6372999; only    1 particles emitted; t= 6.373 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6373999; only    1 particles emitted; t= 6.374 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6374999; only    1 particles emitted; t= 6.375 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6375999; only    1 particles emitted; t= 6.376 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6376999; only    1 particles emitted; t= 6.377 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6377999; only    1 particles emitted; t= 6.378 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6378999; only    1 particles emitted; t= 6.379 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6379999; only    1 particles emitted; t= 6.380 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6380999; only    1 particles emitted; t= 6.381 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6381999; only    1 particles emitted; t= 6.382 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:38 Step 6382999; only    1 particles emitted; t= 6.383 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6383999; only    1 particles emitted; t= 6.384 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6384999; only    1 particles emitted; t= 6.385 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6385999; only    1 particles emitted; t= 6.386 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6386999; only    1 particles emitted; t= 6.387 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6387999; only    1 particles emitted; t= 6.388 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6388999; only    1 particles emitted; t= 6.389 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6389999; only    1 particles emitted; t= 6.390 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6390999; only    1 particles emitted; t= 6.391 [ns], E=139.489 [MeV],
# ParallelTTracker > 18:33:39 Step 6391999; only    1 particles emitted; t= 6.392 [ns], E=139.489 [MeV],
# OPAL >
# OPAL > * ************** B U N C H *********************************************************
# OPAL > * NP              = 1
# OPAL > * Qtot            =        0.000 [fC]         Qi    =        0.000 [fC]
# OPAL > * Ekin            =     139.489 [MeV]         dEkin =        0.000 [eV]
# OPAL > * rmax            = (     -4.13347 ,      0.00000 ,     -1.00649 ) [mm]
# OPAL > * rmin            = (     -4.13347 ,      0.00000 ,     -1.00649 ) [mm]
# OPAL > * hr              = (      0.00001 ,      0.00001 ,      0.00001 ) [um]
# OPAL > * dh              =   1.00000e-10 [%]
# OPAL > * t               =        6.393 [ns]         dT    =        1.000 [fs]
# OPAL > * spos            =         1.916 [m]
# OPAL > * **********************************************************************************
# OPAL >
# OPAL> done executing ParallelTTracker at 18:33:39
# Ippl> Creating new file for data: opal_Monitors.stat
# OPAL> * End of input stream "opal.in".
# Timings> -----------------------------------------------------------------
# Timings>      Timing results for 1 nodes:
# Timings> -----------------------------------------------------------------
# Timings> mainTimer........... Wall tot =    202.475, CPU tot =     202.31
# Timings>
# Timings> Binaryrepart........ Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Boundingbox......... Wall max = 5.7847e-05, CPU max =          0
# Timings>                      Wall avg = 5.7847e-05, CPU avg =          0
# Timings>                      Wall min = 5.7847e-05, CPU min =          0
# Timings>
# Timings> Boundingbox-bounds.. Wall max =  8.661e-06, CPU max =          0
# Timings>                      Wall avg =  8.661e-06, CPU avg =          0
# Timings>                      Wall min =  8.661e-06, CPU min =          0
# Timings>
# Timings> Boundingbox-update.. Wall max =  1.067e-05, CPU max =          0
# Timings>                      Wall avg =  1.067e-05, CPU avg =          0
# Timings>                      Wall min =  1.067e-05, CPU min =          0
# Timings>
# Timings> Compute Statistics.. Wall max = 3.7005e-05, CPU max =          0
# Timings>                      Wall avg = 3.7005e-05, CPU avg =          0
# Timings>                      Wall min = 3.7005e-05, CPU min =          0
# Timings>
# Timings> Create Distr........ Wall max = 0.000769426, CPU max =       0.01
# Timings>                      Wall avg = 0.000769426, CPU avg =       0.01
# Timings>                      Wall min = 0.000769426, CPU min =       0.01
# Timings>
# Timings> External field eval. Wall max =    26.5189, CPU max =      26.91
# Timings>                      Wall avg =    26.5189, CPU avg =      26.91
# Timings>                      Wall min =    26.5189, CPU min =      26.91
# Timings>
# Timings> Fast inside test.... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Histogram........... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Initialize geometry. Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Inside test......... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Load Distr.......... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Particle Inside..... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Ray tracing......... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Secondary emission.. Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> SelfField total..... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> TIntegration1....... Wall max =     21.874, CPU max =      19.88
# Timings>                      Wall avg =     21.874, CPU avg =      19.88
# Timings>                      Wall min =     21.874, CPU min =      19.88
# Timings>
# Timings> TIntegration2....... Wall max =    17.9423, CPU max =      18.02
# Timings>                      Wall avg =    17.9423, CPU avg =      18.02
# Timings>                      Wall min =    17.9423, CPU min =      18.02
# Timings>
# Timings> WakeField........... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> Write H5-File....... Wall max =  0.0334872, CPU max =          0
# Timings>                      Wall avg =  0.0334872, CPU avg =          0
# Timings>                      Wall min =  0.0334872, CPU min =          0
# Timings>
# Timings> Write Stat.......... Wall max =          0, CPU max =          0
# Timings>                      Wall avg =          0, CPU avg =          0
# Timings>                      Wall min =          0, CPU min =          0
# Timings>
# Timings> -----------------------------------------------------------------

# %%
import h5py as h5

# %% [markdown]
# #### Result

# %%
test = h5.File('opal_monitor_dipole_end.h5', 'r')

# %%
for key in test:
    print(key)
# Out:
# Attachment
# Step#0

# %%
# Final x momentum in beta*gamma
test['Step#0/px'][()]
# Out:
# array([-0.86053185])

# %%
# Final x momentum angle
test['Step#0/px'][()]  / test['Step#0/pz'][()]
# Out:
# array([-0.00314097])

# %%
# Deviation from expected
test['Step#0/px'][()]  / test['Step#0/pz'][()] / 1e-3 - r12_dipole(bend_radius, arc_length)
# Out:
# array([0.00062142])

# %% [markdown]
# # ELEGANT

# %%
from rsbeams.rsdata.SDDS import writeSDDS, readSDDS

# %% [markdown]
# #### Create distribution if necessary

# %%
new_distr = writeSDDS()

new_distr.create_column('x', [1e-3,], 'double', colUnits='m')
new_distr.create_column('xp', [0.,], 'double', colUnits='')
new_distr.create_column('y',  [0.,], 'double', colUnits='m')
new_distr.create_column('yp',  [0.,], 'double', colUnits='')
new_distr.create_column('t',  [0.,], 'double', colUnits='s')
new_distr.create_column('p',  [272.973,], 'double', colUnits='')

new_distr.create_parameter('particles', 1, 'long')
new_distr.create_parameter('pCentral', 272.973, 'double', parUnits='MeV/c')

new_distr.save_sdds('bunch_elegant.sdds', dataMode='binary')

# %% [markdown]
# #### Run

# %%
! python sbend.py
# Out:
# Running elegant at Wed Sep  2 19:56:51 2020
#
# This is elegant 2019.3.0, May 30 2020, by M. Borland, J. Calvey, M. Carla', N. Carmignani, M. Ehrlichman, L. Emery, W. Guo, R. Lindberg, V. Sajaev, R. Soliday, Y.-P. Sun, C.-X. Wang, Y. Wang, Y. Wu, and A. Xiao.
# =====================================================================================
# Thanks for using elegant.  Please cite the following reference in your publications:
#   M. Borland, "elegant: A Flexible SDDS-Compliant Code for Accelerator Simulation,"
#   Advanced Photon Source LS-287, September 2000.
# If you use a modified version, please indicate this in all publications.
# =====================================================================================
# Link date: May 30 2020 20:36:55, SVN revision: unknown
# statistics:    ET:     00:00:00 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5662
# &global_settings
#     inhibit_fsync = 0,
#     echo_namelists = 1,
#     mpi_randomization_mode = 3,
#     exact_normalized_emittance = 0,
#     SR_gaussian_limit = 3.000000000000000e+00,
#     inhibit_seed_permutation = 0,
#     log_file = {NULL},
#     error_log_file = {NULL},
#     share_tracking_based_matrices = 1,
#     parallel_tracking_based_matrices = 1,
#     mpi_io_force_file_sync = 0,
#     mpi_io_read_buffer_size = 0,
#     mpi_io_write_buffer_size = 1048576,
#     usleep_mpi_io_kludge = 0,
#     tracking_matrix_step_factor = 1.000000000000000e+00,
#     tracking_matrix_points = 9.000000000000000e+00,
#     tracking_matrix_step_size[0] = 5.000000000000000e-05, 5.000000000000000e-05, 5.000000000000000e-05,
#         5.000000000000000e-05, 5.000000000000000e-05, 5.000000000000000e-05,
# &end
# statistics:    ET:     00:00:00 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5665
# &run_setup
#     lattice = elegant.lte,
#     use_beamline = BL1,
#     rootname = {NULL},
#     output = run_setup.output.sdds,
#     centroid = {NULL},
#     sigma = {NULL},
#     final = {NULL},
#     acceptance = {NULL},
#     losses = {NULL},
#     magnets = {NULL},
#     semaphore_file = {NULL},
#     parameters = {NULL},
#     combine_bunch_statistics = 0,
#     wrap_around = 1,
#     final_pass = 0,
#     default_order = 1,
#     concat_order = 0,
#     print_statistics = 1,
#     show_element_timing = 0,
#     monitor_memory_usage = 0,
#     random_number_seed = 987654321,
#     correction_iterations = 1,
#     echo_lattice = 0,
#     p_central = 0.000000000000000e+00,
#     p_central_mev = 0.000000000000000e+00,
#     always_change_p0 = 0,
#     load_balancing_on = 0,
#     random_sequence_No = 1,
#     expand_for = bunch_elegant.sdds,
#     tracking_updates = 1,
#     search_path = {NULL},
#     element_divisions = 0,
#     back_tracking = 0,
# &end
# Expanding about p = 2.729730000000000e+02
# Seeding random number generators
# computed value for S1.ANGLE is 1.570796326794897e+00
# computed value for S1.L is 5.000000000000000e-01
# length of beamline BL1 per pass: 5.000000000000000e-01 m
# statistics:    ET:     00:00:01 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5702
# &run_control
#     n_steps = 1,
#     bunch_frequency = 0.000000000000000e+00,
#     n_indices = 0,
#     n_passes = 1,
#     n_passes_fiducial = 0,
#     reset_rf_for_each_step = 1,
#     first_is_fiducial = 0,
#     restrict_fiducialization = 0,
#     reset_scattering_seed = 0,
# &end
# statistics:    ET:     00:00:01 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5702
# &twiss_output
#     filename = twiss_output.filename.sdds,
#     matched = 1,
#     output_at_each_step = 0,
#     output_before_tune_correction = 0,
#     final_values_only = 0,
#     statistics = 0,
#     radiation_integrals = 0,
#     beta_x = 1.000000000000000e+00,
#     alpha_x = 0.000000000000000e+00,
#     eta_x = 0.000000000000000e+00,
#     etap_x = 0.000000000000000e+00,
#     beta_y = 1.000000000000000e+00,
#     alpha_y = 0.000000000000000e+00,
#     eta_y = 0.000000000000000e+00,
#     etap_y = 0.000000000000000e+00,
#     reference_file = {NULL},
#     reference_element = {NULL},
#     reference_element_occurrence = 0,
#     reflect_reference_values = 0,
#     concat_order = 3,
#     higher_order_chromaticity = 0,
#     higher_order_chromaticity_points = 5,
#     higher_order_chromaticity_range = 4.000000000000000e-04,
#     quick_higher_order_chromaticity = 0,
#     chromatic_tune_spread_half_range = 0.000000000000000e+00,
#     cavities_are_drifts_if_matched = 1,
#     compute_driving_terms = 0,
#     leading_order_driving_terms_only = 0,
#     s_dependent_driving_terms_file = {NULL},
#     local_dispersion = 1,
#     n_periods = 1,
# &end
# 1 matrices recomputed for periodic Twiss parameter computation
# statistics:    ET:     00:00:01 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5702
# periodic Twiss parameters (chromaticity valid for fully second-order calculation only!):
#          beta          alpha           nu           eta          eta'       dnu/d(dp/p)   dbeta/(dp/p)     accept.
#           m                          1/2pi           m                         1/2pi            m          mm-mrad
# --------------------------------------------------------------------------------------------------------------------
#   x:  3.183099e-01  0.000000e+00  2.500000e-01  3.183099e-01  0.000000e+00 -0.000000e+00  0.000000e+00  0.000000e+00
#   y:  1.077218e+05  5.390015e-12  7.387314e-07  0.000000e+00  0.000000e+00 -0.000000e+00  0.000000e+00  0.000000e+00
# statistics:    ET:     00:00:01 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5773
# &sdds_beam
#     input = bunch_elegant.sdds,
#     input_list = {NULL},
#     input_type = elegant,
#     selection_parameter = {NULL},
#     selection_string = {NULL},
#     one_random_bunch = 0,
#     n_particles_per_ring = 0,
#     reuse_bunch = 0,
#     prebunched = -1,
#     track_pages_separately = 0,
#     use_bunched_mode = 0,
#     fiducialization_bunch = 0,
#     sample_interval = 1,
#     n_tables_to_skip = 0,
#     center_transversely = 0,
#     center_arrival_time = 0,
#     reverse_t_sign = 0,
#     sample_fraction = 1.000000000000000e+00,
#     p_lower = 0.000000000000000e+00,
#     p_upper = 0.000000000000000e+00,
#     save_initial_coordinates = 1,
#     n_duplicates = 0,
#     duplicate_stagger[0] = 0.000000000000000e+00, 0.000000000000000e+00, 0.000000000000000e+00, 0.000000000000000e+00,
#         0.000000000000000e+00, 0.000000000000000e+00,
# &end
# statistics:    ET:     00:00:01 CP:    0.01 BIO:0 DIO:0 PF:0 MEM:5773
# &track
#     center_on_orbit = 0,
#     center_momentum_also = 1,
#     offset_by_orbit = 0,
#     offset_momentum_also = 1,
#     soft_failure = 1,
#     use_linear_chromatic_matrix = 0,
#     longitudinal_ring_only = 0,
#     ibs_only = 0,
#     stop_tracking_particle_limit = -1,
#     check_beam_structure = 0,
#     interrupt_file = %s.interrupt,
# &end
# tracking step 1
# 2 Sep 20 19:56:52: Starting to read beam from SDDS file.
# Warning: p has no units.  Expected m$be$nc
# File bunch_elegant.sdds opened and checked.
# Read page 1 from file
# 0 particle ID slots per bunch
# 1 rows in page 1
# File bunch_elegant.sdds was used up and closed.
# 2 Sep 20 19:56:52: Done reading beam from SDDS file.
# a total of 1 data points were read
#
# tracking 1 particles
# 2 Sep 20 19:56:52: This step establishes energy profile vs s (fiducial beam).
# 2 Sep 20 19:56:52: Rf phases/references reset.
# Starting W0#1 at s=0.000000e+00 m, pass 0, 1 particles, memory 5773 kB
# Starting S1#1 at s=0.000000e+00 m, pass 0, 1 particles, memory 5773 kB
# Starting W1#1 at s=5.000000e-01 m, pass 0, 1 particles, memory 5773 kB
# 1 particles transmitted, total effort of 1 particle-turns
# 0 multipole kicks done
#
# Dumping output beam data...done.
# Post-tracking output completed.
# Tracking step completed   ET:     00:00:01 CP:    0.02 BIO:0 DIO:0 PF:0 MEM:5906
#
#
# Finished tracking.
# End of input data encountered.
# statistics:    ET:     00:00:01 CP:    0.02 BIO:0 DIO:0 PF:0 MEM:5906
# =====================================================================================
# Thanks for using elegant.  Please cite the following reference in your publications:
#   M. Borland, "elegant: A Flexible SDDS-Compliant Code for Accelerator Simulation,"
#   Advanced Photon Source LS-287, September 2000.
# If you use a modified version, please indicate this in all publications.
# =====================================================================================

# %% [markdown]
# #### Result

# %%
elegant_out = readSDDS('W1.filename.sdds')
elegant_out.read()
# Out:
# &description &description text="watch-point phase space--input: elegant.ele  lattice: elegant.lte", contents="watch-point phase space", &end
#  not parsed
# Could not read page 1

# %%
# Final x momentum as angle
elegant_out.columns['xp']
# Out:
# array([[-0.00314159]])

# %%
# Deviation from expected result
elegant_out.columns['xp'] / 1e-3 - r12_dipole(bend_radius, arc_length)
# Out:
# array([[0.]])
